# %% [markdown]
# # Sparkify Project Workspace
#
# The aim of this project is to train a classification algorithm to predict user churning based upon information contained in user log data. More specifically, the data relates to a fictitious music streaming service called Sparkify.
#
# In order to be able to locally run the initial analysis, I first did some basic analysis on a small subset (128 MB) of the full dataset (12 GB).
#
# While the smaller version of the dataset is small enough to fit into the memory of a local machine, the full dataset is likely to cause issues due to its large size. Hence, in order to deal with this, it is necessary to make use of distributed computing. As the name of the fictitious streaming service "Sparkify" already implies, this project uses Spark or more specifically the Python API PySpark to deal with the large dataset. PySpark as a high-level API allows us to focus on working with the data without having to dive too deep into the principles of distributed computing.
#
# This version of the Jupyter notebook was adapted to run on an AWS EMS cluster. Please note that the repository also contains a version of this notebook which you can run locally.
#
#
# ## Structure
#
# The project starts off with loading the data, dropping cases where there were no user IDs and a first investigation of the data.
#
# Following this, the target variable (whether a user has churned or not) is defined and several features at the user level are created. The latter is an important point because while the original log data contains many rows for each individual user, in order to perform binary classification we will need to have only one row for each user.
#
# These features are then compared across the two user groups, i.e. those who have churned and those who have not, to identify features which may help in predicting users' behaviour.
#
# New components of features which have over 90% of the total variance are then created with PCA.Before the data is split into a train and a test set, numerical features are scaled using standard scaler scaling and categorical features are encoded using one-hot encoding.
#
# The training and test datasets are then used to compare a logistic regression, random forest classifier,and a decision tree classifier. The models are evaluated using the F1 score to account for the imbalanced nature of the dataset (i.e. there are only few users who have actually churned).
#
# The best model is then chosen and optimised by using hyperparameter tuning.
#
# Finally, the results of the optimised model are briefly discussed

# %%
# import libraries
import pyspark
from pyspark import SparkConf
from pyspark.sql import SparkSession, Window
from pyspark.sql.functions import isnan, when, count, col, isnan, isnull, udf, last, first, struct, lit, approx_count_distinct
from pyspark.sql.functions import sum as Fsum
from pyspark.sql.functions import when as Fwhen
from pyspark.sql.functions import lag as Flag
from pyspark.sql.functions import isnull as Fisnull
from pyspark.sql.types import IntegerType, DoubleType
from pyspark.ml.feature import StringIndexer, OneHotEncoderEstimator, MinMaxScaler, VectorAssembler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.classification import LinearSVC
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.classification import NaiveBayes
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, Evaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.feature import PCA
from pyspark.ml.linalg import Vectors

import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import seaborn as sns
from datetime import datetime
import pandas as pd
import numpy as np
# Magic command to display plots inline
# %matplotlib inline

import plotly.plotly as py
import plotly.graph_objs as go
import warnings
warnings.filterwarnings("ignore")

from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.ml import feature as FT
from pyspark.ml.tuning import ParamGridBuilder

# %%
# create a Spark session
spark = SparkSession \
    .builder \
    .appName("Sparkify") \
    .getOrCreate()

# %% [markdown]
# # Load and Clean Dataset
# In this workspace, the mini-dataset file is `mini_sparkify_event_data.json`. Load and clean the dataset, checking for invalid or missing data - for example, records without userids or sessionids.

# %%
# Read in full sparkify dataset
# event_data = "s3n://udacity-dsnd/sparkify/mini_sparkify_event_data.json"
df = spark.read.json('mini_sparkify_event_data.json')
df.head()

# %% [markdown]
# # Exploratory Data Analysis
#
#
#
#
# ### Explore Data
#
# Let's perform some exploratory data analysis to observe the behavior for users who stayed vs users who churned. we will explore the aggregation on these two groups of users, observing how much of a specific action they experienced per a certain time unit or number of songs played.

# %%
df.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
df.select('page').dropDuplicates().sort('page').show()
# Out:
# +--------------------+
# |                page|
# +--------------------+
# |               About|
# |          Add Friend|
# |     Add to Playlist|
# |              Cancel|
# |Cancellation Conf...|
# |           Downgrade|
# |               Error|
# |                Help|
# |                Home|
# |              Logout|
# |            NextSong|
# |         Roll Advert|
# |       Save Settings|
# |            Settings|
# |    Submit Downgrade|
# |      Submit Upgrade|
# |         Thumbs Down|
# |           Thumbs Up|
# |             Upgrade|
# +--------------------+

# %%
df.toPandas()
# Out:
#                                     artist        auth firstName gender  \
# 0                           Martha Tilston   Logged In     Colin      M
# 1                         Five Iron Frenzy   Logged In     Micah      M
# 2                             Adam Lambert   Logged In     Colin      M
# 3                                   Enigma   Logged In     Micah      M
# 4                                Daft Punk   Logged In     Colin      M
# 5                 The All-American Rejects   Logged In     Micah      M
# 6            The Velvet Underground / Nico   Logged In     Micah      M
# 7                             Starflyer 59   Logged In     Colin      M
# 8                                     None   Logged In     Colin      M
# 9                                 Frumpies   Logged In     Colin      M
# 10                            Britt Nicole   Logged In     Micah      M
# 11                                    None   Logged In     Micah      M
# 12      Edward Sharpe & The Magnetic Zeros   Logged In     Colin      M
# 13                                   Tesla   Logged In     Micah      M
# 14                                    None   Logged In     Micah      M
# 15                             Stan Mosley   Logged In     Colin      M
# 16                  Florence + The Machine   Logged In     Micah      M
# 17                       Tokyo Police Club   Logged In   Ashlynn      F
# 18                                 Orishas   Logged In     Colin      M
# 19                                 Ratatat   Logged In     Micah      M
# 20                           Manolo Garcia   Logged In   Ashlynn      F
# 21                                Downhere   Logged In     Colin      M
# 22                                   Modjo   Logged In     Alexi      F
# 23                       MÃÂ¶tley CrÃÂ¼e   Logged In     Micah      M
# 24                             David Bowie   Logged In   Ashlynn      F
# 25                                 Skillet   Logged In     Colin      M
# 26                           Edwyn Collins   Logged In     Alexi      F
# 27                            Telepopmusik   Logged In     Micah      M
# 28                           Kings Of Leon   Logged In   Ashlynn      F
# 29                  Florence + The Machine   Logged In     Colin      M
# ...                                    ...         ...       ...    ...
# 286485             31     House  273.94567  paid
# 286486             32     House  655.77751  paid
# 286487             33     House  225.30567  paid
# 286488             34     House  241.52771  paid
# 286489             35     House  420.46649  paid
# 286490             36     House        NaN  paid
# 286491             37     House  264.12363  paid
# 286492             38     House  258.66404  paid
# 286493             39     House        NaN  paid
# 286494             40      None        NaN  paid
# 286495             41      None        NaN  paid
# 286496             42      None        NaN  paid
# 286497             43     House        NaN  paid
# 286498             44     House        NaN  paid
# 286499             45     House  170.89261  paid
#
#                                      location method             page  \
# 0                             Bakersfield, CA    PUT         NextSong
# 1              Boston-Cambridge-Newton, MA-NH    PUT         NextSong
# 2                             Bakersfield, CA    PUT         NextSong
# 3              Boston-Cambridge-Newton, MA-NH    PUT         NextSong
# 4                             Bakersfield, CA    PUT         NextSong
# 5              Boston-Cambridge-Newton, MA-NH    PUT         NextSong
# 6              Boston-Cambridge-Newton, MA-NH    PUT         NextSong
# 7                             Bakersfield, CA    PUT         NextSong
# 8                             Bakersfield, CA    PUT  Add to Playlist
# 9                             Bakersfield, CA    PUT         NextSong
# 10             Boston-Cambridge-Newton, MA-NH    PUT         NextSong
# 11             Boston-Cambridge-Newton, MA-NH    GET      Roll Advert
# 12                            Bakersfield, CA    PUT         NextSong
# 13             Boston-Cambridge-Newton, MA-NH    PUT         NextSong
# 14             Boston-Cambridge-Newton, MA-NH    PUT        Thumbs Up
# 15                            Bakersfield, CA    PUT         NextSong
# 16             Boston-Cambridge-Newton, MA-NH    PUT         NextSong
# 17                            Tallahassee, FL    PUT         NextSong
# 18                            Bakersfield, CA    PUT         NextSong
# 19             Boston-Cambridge-Newton, MA-NH    PUT         NextSong
# 20                            Tallahassee, FL    PUT         NextSong
# 21                            Bakersfield, CA    PUT         NextSong
# 22                 Spokane-Spokane Valley, WA    PUT         NextSong
# 23             Boston-Cambridge-Newton, MA-NH    PUT         NextSong
# 24                            Tallahassee, FL    PUT         NextSong
# 25                            Bakersfield, CA    PUT         NextSong
# 26                 Spokane-Spokane Valley, WA    PUT         NextSong
# 27             Boston-Cambridge-Newton, MA-NH    PUT         NextSong
# 28                            Tallahassee, FL    PUT         NextSong
# 29                            Bakersfield, CA    PUT         NextSong
# ...                                       ...    ...              ...
# 286470  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286471  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286472  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286473  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286474  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286475  New York-Newark-Jersey City, NY-NJ-PA    PUT        Thumbs Up
# 286476  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286477  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286478  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286479  New York-Newark-Jersey City, NY-NJ-PA    PUT       Add Friend
# 286480  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286481  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286482  New York-Newark-Jersey City, NY-NJ-PA    GET             Home
# 286483  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286484  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286485  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286486  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286487  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286488  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286489  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286490  New York-Newark-Jersey City, NY-NJ-PA    GET             Home
# 286491  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286492  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
# 286493  New York-Newark-Jersey City, NY-NJ-PA    PUT           Logout
# 286494                                   None    GET             Home
# 286495                                   None    GET             Home
# 286496                                   None    PUT            Login
# 286497  New York-Newark-Jersey City, NY-NJ-PA    GET             Home
# 286498  New York-Newark-Jersey City, NY-NJ-PA    GET            About
# 286499  New York-Newark-Jersey City, NY-NJ-PA    PUT         NextSong
#
#         registration  sessionId  \
# 0       1.538173e+12         29
# 1       1.538332e+12          8
# 2       1.538173e+12         29
# 3       1.538332e+12          8
# 4       1.538173e+12         29
# 5       1.538332e+12          8
# 6       1.538332e+12          8
# 7       1.538173e+12         29
# 8       1.538173e+12         29
# 9       1.538173e+12         29
# 10      1.538332e+12          8
# 11      1.538332e+12          8
# 12      1.538173e+12         29
# 13      1.538332e+12          8
# 14      1.538332e+12          8
# 15      1.538173e+12         29
# 16      1.538332e+12          8
# 17      1.537365e+12        217
# 18      1.538173e+12         29
# 19      1.538332e+12          8
# 20      1.537365e+12        217
# 21      1.538173e+12         29
# 22      1.532483e+12         53
# 23      1.538332e+12          8
# 24      1.537365e+12        217
# 25      1.538173e+12         29
# 26      1.532483e+12         53
# 27      1.538332e+12          8
# 28      1.537365e+12        217
# 29      1.538173e+12         29
# ...              ...        ...
# 286470  1.538337e+12        500
# 286471  1.538337e+12        500
# 286472  1.538337e+12        500
# 286473  1.538337e+12        500
# 286474  1.538337e+12        500
# 286475  1.538337e+12        500
# 286476  1.538337e+12        500
# 286477  1.538337e+12        500
# 286478  1.538337e+12        500
# 286479  1.538337e+12        500
# 286480  1.538337e+12        500
# 286481  1.538337e+12        500
# 286482  1.538337e+12        500
# 286483  1.538337e+12        500
# 286484  1.538337e+12        500
# 286485  1.538337e+12        500
# 286486  1.538337e+12        500
# 286487  1.538337e+12        500
# 286488  1.538337e+12        500
# 286489  1.538337e+12        500
# 286490  1.538337e+12        500
# 286491  1.538337e+12        500
# 286492  1.538337e+12        500
# 286493  1.538337e+12        500
# 286494           NaN        500
# 286495           NaN        500
# 286496           NaN        500
# 286497  1.538337e+12        500
# 286498  1.538337e+12        500
# 286499  1.538337e+12        500
#
#                                                      song  status  \
# 0                                               Rockpools     200
# 1                                                  Canada     200
# 2                                       Time For Miracles     200
# 3                             Knocking On Forbidden Doors     200
# 4                           Harder Better Faster Stronger     200
# 5                                          Don't Leave Me     200
# 6                                             Run Run Run     200
# 7                          Passengers (Old Album Version)     200
# 8                                                    None     200
# 9                                              Fuck Kitty     200
# 10                                      Walk On The Water     200
# 11                                                   None     200
# 12                                                   Jade     200
# 13                                         Gettin' Better     200
# 14                                                   None     307
# 15                                      So-Called Friends     200
# 16                                    You've Got The Love     200
# 17                                   Citizens Of Tomorrow     200
# 18                                              Represent     200
# 19                                                 Swisha     200
# 20                                   Carbon Y Ramas Secas     200
# 21                                              Here I Am     200
# 22                                            What I Mean     200
# 23                                           Sticky Sweet     200
# 24                         Sorrow (1997 Digital Remaster)     200
# 25                             Rebirthing (Album Version)     200
# 26         You'll Never Know (My Love) (Bovellian 07 Mix)     200
# 27                                                  Smile     200
# 28                                             I Want You     200
# 29                         Dog Days Are Over (Radio Edit)     200
# ...                                                   ...     ...
# 286470                                          Lucky Day     200
# 286471                   Jamaica Roots II(Agora E Sempre)     200
# 286472                               Embody the invisible     200
# 286473                                        Mockingbird     200
# 286474                                       Feeling This     200
# 286475                                               None     307
# 286476                  Geek In The Pink [Phil Tan Remix]     200
# 286477                                    Greater Heights     200
# 286478                                     Bleeding Heart     200
# 286479                                               None     307
# 286480                                DJ Play A Love Song     200
# 286481                                  More Than A Woman     200
# 286482                                               None     200
# 286483                                Letters From Madrid     200
# 286484                                 King Of The Stereo     200
# 286485  Shining Down [feat. Matthew Santos] (Amended A...     200
# 286486                                      Sehr kosmisch     200
# 286487                                               Tops     200
# 286488                                  Tu no tienes alma     200
# 286489                                       Bala Bay Inn     200
# 286490                                               None     200
# 286491                                   You're Not Alone     200
# 286492  Murders In The Rue Morgue (1998 Digital Remaster)     200
# 286493                                               None     307
# 286494                                               None     200
# 286495                                               None     200
# 286496                                               None     307
# 286497                                               None     200
# 286498                                               None     200
# 286499                                The Sun On His Back     200
#
#                    ts                                          userAgent  \
# 0       1538352117000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 1       1538352180000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 2       1538352394000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 3       1538352416000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 4       1538352676000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 5       1538352678000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 6       1538352886000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 7       1538352899000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 8       1538352905000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 9       1538353084000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 10      1538353146000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 11      1538353150000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 12      1538353218000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 13      1538353375000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 14      1538353376000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 15      1538353441000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 16      1538353576000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 17      1538353668000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 18      1538353687000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 19      1538353744000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 20      1538353834000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 21      1538353909000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 22      1538353930000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...
# 23      1538353973000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 24      1538354117000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 25      1538354132000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 26      1538354180000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...
# 27      1538354204000  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 28      1538354291000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 29      1538354365000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# ...               ...                                                ...
# 286470  1543617391000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286471  1543617592000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286472  1543617802000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286473  1543618019000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286474  1543618269000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286475  1543618270000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286476  1543618442000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286477  1543618660000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286478  1543618840000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286479  1543618841000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286480  1543619220000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286481  1543619478000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286482  1543619556000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286483  1543619706000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286484  1543619821000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286485  1543620043000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286486  1543620316000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286487  1543620971000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286488  1543621196000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286489  1543621437000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286490  1543621485000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286491  1543621857000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286492  1543622121000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286493  1543622122000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286494  1543622135000                                               None
# 286495  1543622240000                                               None
# 286496  1543622241000                                               None
# 286497  1543622248000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286498  1543622398000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 286499  1543622411000  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#         userId
# 0           30
# 1            9
# 2           30
# 3            9
# 4           30
# 5            9
# 6            9
# 7           30
# 8           30
# 9           30
# 10           9
# 11           9
# 12          30
# 13           9
# 14           9
# 15          30
# 16           9
# 17          74
# 18          30
# 19           9
# 20          74
# 21          30
# 22          54
# 23           9
# 24          74
# 25          30
# 26          54
# 27           9
# 28          74
# 29          30
# ...        ...
# 286470  300011
# 286471  300011
# 286472  300011
# 286473  300011
# 286474  300011
# 286475  300011
# 286476  300011
# 286477  300011
# 286478  300011
# 286479  300011
# 286480  300011
# 286481  300011
# 286482  300011
# 286483  300011
# 286484  300011
# 286485  300011
# 286486  300011
# 286487  300011
# 286488  300011
# 286489  300011
# 286490  300011
# 286491  300011
# 286492  300011
# 286493  300011
# 286494
# 286495
# 286496
# 286497  300011
# 286498  300011
# 286499  300011
#
# [286500 rows x 18 columns]

# %%
df.count()
# Out:
# 286500

# %% [markdown]
# Checking missing values

# %%
nan_count = df.select([count(when(isnan(c), c)).alias(c) for c in df.columns]).toPandas()
nan_count
# Out:
#    artist  auth  firstName  gender  itemInSession  lastName  length  level  \
# 0       0     0          0       0              0         0       0      0
#
#    location  method  page  registration  sessionId  song  status  ts  \
# 0         0       0     0             0          0     0       0   0
#
#    userAgent  userId
# 0          0       0

# %%
null_count = df.select([count(when(isnull(c), c)).alias(c) for c in df.columns]).toPandas()
null_count
# Out:
#    artist  auth  firstName  gender  itemInSession  lastName  length  level  \
# 0   58392     0       8346    8346              0      8346   58392      0
#
#    location  method  page  registration  sessionId   song  status  ts  \
# 0      8346       0     0          8346          0  58392       0   0
#
#    userAgent  userId
# 0       8346       0

# %%
df.where(col('artist').isNull()).toPandas()
# Out:
#       artist        auth firstName gender  itemInSession  lastName length  \
# 0       None   Logged In     Colin      M             54   Freeman   None
# 1       None   Logged In     Micah      M             84      Long   None
# 2       None   Logged In     Micah      M             86      Long   None
# 3       None   Logged In     Alexi      F              4    Warren   None
# 4       None   Logged In     Alexi      F              7    Warren   None
# 5       None   Logged In     Micah      M             95      Long   None
# 6       None   Logged In     Micah      M             97      Long   None
# 7       None   Logged In     Micah      M             99      Long   None
# 8       None   Logged In   Ashlynn      F              9  Williams   None
# 9       None  Logged Out      None   None            100      None   None
# 10      None  Logged Out      None   None            101      None   None
# 11      None  Logged Out      None   None            102      None   None
# 12      None  Logged Out      None   None            103      None   None
# 13      None   Logged In     Micah      M            104      Long   None
# 14      None   Logged In     Colin      M             71   Freeman   None
# 15      None   Logged In    Warren      M              1    Miller   None
# 16      None  Logged Out      None   None              2      None   None
# 17      None  Logged Out      None   None              3      None   None
# 18      None   Logged In    Warren      M              4    Miller   None
# 19      None   Logged In   Ashlynn      F             15  Williams   None
# 20      None   Logged In    Warren      M              6    Miller   None
# 21      None   Logged In   Ashlynn      F             18  Williams   None
# 22      None   Logged In     Micah      M            111      Long   None
# 23      None   Logged In     Colin      M             77   Freeman   None
# 24      None   Logged In   Ashlynn      F             22  Williams   None
# 25      None   Logged In     Colin      M             79   Freeman   None
# 26      None  Logged Out      None   None              0      None   None
# 27      None   Logged In   Ashlynn      F             24  Williams   None
# 28      None   Logged In      Alex      M              1     Hogan   None
# 29      None   Logged In     Micah      M            119      Long   None
# ...      ...         ...       ...    ...            ...       ...    ...
# 58362   None   Logged In    Lauren      F             26     Boone   None
# 58363   None   Logged In    Lauren      F             31     Boone   None
# 58364   None  Logged Out      None   None             32      None   None
# 58365   None  Logged Out      None   None             33      None   None
# 58366   None  Logged Out      None   None             34      None   None
# 58367   None   Logged In    Lauren      F             35     Boone   None
# 58368   None   Logged In    Lauren      F             36     Boone   None
# 58369   None   Logged In      Emma      F              3     Allen   None
# 58370   None  Logged Out      None   None              4      None   None
# 58371   None  Logged Out      None   None              5      None   None
# 58372   None  Logged Out      None   None              6      None   None
# 58373   None   Logged In      Emma      F              7     Allen   None
# 58374   None   Logged In    Lauren      F             41     Boone   None
# 58375   None   Logged In    Lauren      F             43     Boone   None
# 58376   None   Logged In      Emma      F             23     Allen   None
# 58377   None   Logged In      Emma      F             27     Allen   None
# 58378   None   Logged In      Emma      F             29     Allen   None
# 58379   None   Logged In    Emilia      F              2     House   None
# 58380   None   Logged In    Emilia      F              5     House   None
# 58381   None   Logged In    Emilia      F             15     House   None
# 58382   None   Logged In    Emilia      F             21     House   None
# 58383   None   Logged In    Emilia      F             25     House   None
# 58384   None   Logged In    Emilia      F             28     House   None
# 58385   None   Logged In    Emilia      F             36     House   None
# 58386   None   Logged In    Emilia      F             39     House   None
# 58387   None  Logged Out      None   None             40      None   None
# 58388   None  Logged Out      None   None             41      None   None
# 58389   None  Logged Out      None   None             42      None   None
# 58390   None   Logged In    Emilia      F             43     House   None
# 58391   None   Logged In    Emilia      F             44     House   None
#
#       level                               location method             page  \
# 0      paid                        Bakersfield, CA    PUT  Add to Playlist
# 1      free         Boston-Cambridge-Newton, MA-NH    GET      Roll Advert
# 2      free         Boston-Cambridge-Newton, MA-NH    PUT        Thumbs Up
# 3      paid             Spokane-Spokane Valley, WA    GET        Downgrade
# 4      paid             Spokane-Spokane Valley, WA    PUT        Thumbs Up
# 5      free         Boston-Cambridge-Newton, MA-NH    PUT      Thumbs Down
# 6      free         Boston-Cambridge-Newton, MA-NH    GET             Home
# 7      free         Boston-Cambridge-Newton, MA-NH    PUT           Logout
# 8      free                        Tallahassee, FL    PUT        Thumbs Up
# 9      free                                   None    GET             Home
# 10     free                                   None    GET             Help
# 11     free                                   None    GET             Home
# 12     free                                   None    PUT            Login
# 13     free         Boston-Cambridge-Newton, MA-NH    GET             Home
# 14     paid                        Bakersfield, CA    PUT      Thumbs Down
# 15     free          Baltimore-Columbia-Towson, MD    PUT           Logout
# 16     free                                   None    GET             Home
# 17     free                                   None    PUT            Login
# 18     free          Baltimore-Columbia-Towson, MD    GET             Home
# 19     free                        Tallahassee, FL    PUT  Add to Playlist
# 20     free          Baltimore-Columbia-Towson, MD    GET             Home
# 21     free                        Tallahassee, FL    PUT        Thumbs Up
# 22     free         Boston-Cambridge-Newton, MA-NH    PUT        Thumbs Up
# 23     paid                        Bakersfield, CA    PUT        Thumbs Up
# 24     free                        Tallahassee, FL    PUT        Thumbs Up
# 25     paid                        Bakersfield, CA    PUT        Thumbs Up
# 26     free                                   None    PUT            Login
# 27     free                        Tallahassee, FL    PUT      Thumbs Down
# 28     free             Denver-Aurora-Lakewood, CO    GET             Home
# 29     free         Boston-Cambridge-Newton, MA-NH    GET      Roll Advert
# ...     ...                                    ...    ...              ...
# 58362  paid                       St. Louis, MO-IL    PUT        Thumbs Up
# 58363  paid                       St. Louis, MO-IL    PUT           Logout
# 58364  paid                                   None    GET             Home
# 58365  paid                                   None    GET            About
# 58366  paid                                   None    PUT            Login
# 58367  paid                       St. Louis, MO-IL    GET             Home
# 58368  paid                       St. Louis, MO-IL    PUT       Add Friend
# 58369  paid                             Wilson, NC    PUT           Logout
# 58370  paid                                   None    GET             Home
# 58371  paid                                   None    GET             Home
# 58372  paid                                   None    PUT            Login
# 58373  paid                             Wilson, NC    GET             Home
# 58374  paid                       St. Louis, MO-IL    PUT        Thumbs Up
# 58375  paid                       St. Louis, MO-IL    GET             Home
# 58376  paid                             Wilson, NC    PUT      Thumbs Down
# 58377  paid                             Wilson, NC    GET             Home
# 58378  paid                             Wilson, NC    GET             Home
# 58379  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT        Thumbs Up
# 58380  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT      Thumbs Down
# 58381  paid  New York-Newark-Jersey City, NY-NJ-PA    GET             Home
# 58382  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT        Thumbs Up
# 58383  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT       Add Friend
# 58384  paid  New York-Newark-Jersey City, NY-NJ-PA    GET             Home
# 58385  paid  New York-Newark-Jersey City, NY-NJ-PA    GET             Home
# 58386  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT           Logout
# 58387  paid                                   None    GET             Home
# 58388  paid                                   None    GET             Home
# 58389  paid                                   None    PUT            Login
# 58390  paid  New York-Newark-Jersey City, NY-NJ-PA    GET             Home
# 58391  paid  New York-Newark-Jersey City, NY-NJ-PA    GET            About
#
#        registration  sessionId  song  status             ts  \
# 0      1.538173e+12         29  None     200  1538352905000
# 1      1.538332e+12          8  None     200  1538353150000
# 2      1.538332e+12          8  None     307  1538353376000
# 3      1.532483e+12         53  None     200  1538354749000
# 4      1.532483e+12         53  None     307  1538355255000
# 5      1.538332e+12          8  None     307  1538355306000
# 6      1.538332e+12          8  None     200  1538355504000
# 7      1.538332e+12          8  None     307  1538355687000
# 8      1.537365e+12        217  None     307  1538355711000
# 9               NaN          8  None     200  1538355745000
# 10              NaN          8  None     200  1538355807000
# 11              NaN          8  None     200  1538355841000
# 12              NaN          8  None     307  1538355842000
# 13     1.538332e+12          8  None     200  1538355855000
# 14     1.538173e+12         29  None     307  1538356524000
# 15     1.538170e+12        240  None     307  1538356651000
# 16              NaN        240  None     200  1538356678000
# 17              NaN        240  None     307  1538356679000
# 18     1.538170e+12        240  None     200  1538356686000
# 19     1.537365e+12        217  None     200  1538356816000
# 20     1.538170e+12        240  None     200  1538356954000
# 21     1.537365e+12        217  None     307  1538357104000
# 22     1.538332e+12          8  None     307  1538357160000
# 23     1.538173e+12         29  None     307  1538357649000
# 24     1.537365e+12        217  None     307  1538357916000
# 25     1.538173e+12         29  None     307  1538357991000
# 26              NaN        100  None     307  1538358102000
# 27     1.537365e+12        217  None     307  1538358192000
# 28     1.535066e+12        100  None     200  1538358605000
# 29     1.538332e+12          8  None     200  1538358779000
# ...             ...        ...   ...     ...            ...
# 58362  1.534860e+12        485  None     307  1543603099000
# 58363  1.534860e+12        485  None     307  1543604084000
# 58364           NaN        485  None     200  1543604143000
# 58365           NaN        485  None     200  1543604164000
# 58366           NaN        485  None     307  1543604165000
# 58367  1.534860e+12        485  None     200  1543604239000
# 58368  1.534860e+12        485  None     307  1543604240000
# 58369  1.537612e+12        498  None     307  1543604493000
# 58370           NaN        498  None     200  1543604533000
# 58371           NaN        498  None     200  1543604776000
# 58372           NaN        498  None     307  1543604777000
# 58373  1.537612e+12        498  None     200  1543604786000
# 58374  1.534860e+12        485  None     307  1543605019000
# 58375  1.534860e+12        485  None     200  1543605457000
# 58376  1.537612e+12        498  None     307  1543608481000
# 58377  1.537612e+12        498  None     200  1543609421000
# 58378  1.537612e+12        498  None     200  1543609683000
# 58379  1.538337e+12        500  None     307  1543614016000
# 58380  1.538337e+12        500  None     307  1543614528000
# 58381  1.538337e+12        500  None     200  1543617317000
# 58382  1.538337e+12        500  None     307  1543618270000
# 58383  1.538337e+12        500  None     307  1543618841000
# 58384  1.538337e+12        500  None     200  1543619556000
# 58385  1.538337e+12        500  None     200  1543621485000
# 58386  1.538337e+12        500  None     307  1543622122000
# 58387           NaN        500  None     200  1543622135000
# 58388           NaN        500  None     200  1543622240000
# 58389           NaN        500  None     307  1543622241000
# 58390  1.538337e+12        500  None     200  1543622248000
# 58391  1.538337e+12        500  None     200  1543622398000
#
#                                                userAgent  userId
# 0      Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...      30
# 1      "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       9
# 2      "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       9
# 3      Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...      54
# 4      Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...      54
# 5      "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       9
# 6      "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       9
# 7      "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       9
# 8      "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      74
# 9                                                   None
# 10                                                  None
# 11                                                  None
# 12                                                  None
# 13     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       9
# 14     Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...      30
# 15     Mozilla/5.0 (Windows NT 6.0; rv:31.0) Gecko/20...       4
# 16                                                  None
# 17                                                  None
# 18     Mozilla/5.0 (Windows NT 6.0; rv:31.0) Gecko/20...       4
# 19     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      74
# 20     Mozilla/5.0 (Windows NT 6.0; rv:31.0) Gecko/20...       4
# 21     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      74
# 22     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       9
# 23     Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...      30
# 24     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      74
# 25     Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...      30
# 26                                                  None
# 27     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      74
# 28     Mozilla/5.0 (Windows NT 6.2; WOW64; rv:31.0) G...     101
# 29     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       9
# ...                                                  ...     ...
# 58362  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  300009
# 58363  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  300009
# 58364                                               None
# 58365                                               None
# 58366                                               None
# 58367  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  300009
# 58368  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  300009
# 58369  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  300021
# 58370                                               None
# 58371                                               None
# 58372                                               None
# 58373  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  300021
# 58374  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  300009
# 58375  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  300009
# 58376  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  300021
# 58377  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  300021
# 58378  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  300021
# 58379  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...  300011
# 58380  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...  300011
# 58381  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...  300011
# 58382  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...  300011
# 58383  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...  300011
# 58384  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...  300011
# 58385  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...  300011
# 58386  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...  300011
# 58387                                               None
# 58388                                               None
# 58389                                               None
# 58390  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...  300011
# 58391  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...  300011
#
# [58392 rows x 18 columns]

# %%
df.where(col('artist').isNotNull()).toPandas()
# Out:
#                                     artist       auth firstName gender  \
# 0                           Martha Tilston  Logged In     Colin      M
# 1                         Five Iron Frenzy  Logged In     Micah      M
# 2                             Adam Lambert  Logged In     Colin      M
# 3                                   Enigma  Logged In     Micah      M
# 4                                Daft Punk  Logged In     Colin      M
# 5                 The All-American Rejects  Logged In     Micah      M
# 6            The Velvet Underground / Nico  Logged In     Micah      M
# 7                             Starflyer 59  Logged In     Colin      M
# 8                                 Frumpies  Logged In     Colin      M
# 9                             Britt Nicole  Logged In     Micah      M
# 10      Edward Sharpe & The Magnetic Zeros  Logged In     Colin      M
# 11                                   Tesla  Logged In     Micah      M
# 12                             Stan Mosley  Logged In     Colin      M
# 13                  Florence + The Machine  Logged In     Micah      M
# 14                       Tokyo Police Club  Logged In   Ashlynn      F
# 15                                 Orishas  Logged In     Colin      M
# 16                                 Ratatat  Logged In     Micah      M
# 17                           Manolo Garcia  Logged In   Ashlynn      F
# 18                                Downhere  Logged In     Colin      M
# 19                                   Modjo  Logged In     Alexi      F
# 20                       MÃÂ¶tley CrÃÂ¼e  Logged In     Micah      M
# 21                             David Bowie  Logged In   Ashlynn      F
# 22                                 Skillet  Logged In     Colin      M
# 23                           Edwyn Collins  Logged In     Alexi      F
# 24                            Telepopmusik  Logged In     Micah      M
# 25                           Kings Of Leon  Logged In   Ashlynn      F
# 26                  Florence + The Machine  Logged In     Colin      M
# 27                                Coldplay  Logged In     Alexi      F
# 28                         Nine Inch Nails  Logged In     Micah      M
# 29                              Nick Drake  Logged In     Colin      M
# ...                                    ...        ...       ...    ...
# 228078                            Calle 13  Logged In    Emilia      F
# 228079                    Public Image Ltd  Logged In    Emilia      F
# 228080              Florence + The Machine  Logged In    Emilia      F
# 228081                          Luke Bryan  Logged In    Emilia      F
# 228082                        Junior Kelly  Logged In    Emilia      F
# 228083                            Coldplay  Logged In    Emilia      F
# 228084           Usher featuring will.i.am  Logged In    Emilia      F
# 228085                  Taking Back Sunday  Logged In    Emilia      F
# 228086                                Muse  Logged In    Emilia      F
# 228102             33     House  225.30567  paid
# 228103             34     House  241.52771  paid
# 228104             35     House  420.46649  paid
# 228105             37     House  264.12363  paid
# 228106             38     House  258.66404  paid
# 228107             45     House  170.89261  paid
#
#                                      location method      page   registration  \
# 0                             Bakersfield, CA    PUT  NextSong  1538173362000
# 1              Boston-Cambridge-Newton, MA-NH    PUT  NextSong  1538331630000
# 2                             Bakersfield, CA    PUT  NextSong  1538173362000
# 3              Boston-Cambridge-Newton, MA-NH    PUT  NextSong  1538331630000
# 4                             Bakersfield, CA    PUT  NextSong  1538173362000
# 5              Boston-Cambridge-Newton, MA-NH    PUT  NextSong  1538331630000
# 6              Boston-Cambridge-Newton, MA-NH    PUT  NextSong  1538331630000
# 7                             Bakersfield, CA    PUT  NextSong  1538173362000
# 8                             Bakersfield, CA    PUT  NextSong  1538173362000
# 9              Boston-Cambridge-Newton, MA-NH    PUT  NextSong  1538331630000
# 10                            Bakersfield, CA    PUT  NextSong  1538173362000
# 11             Boston-Cambridge-Newton, MA-NH    PUT  NextSong  1538331630000
# 12                            Bakersfield, CA    PUT  NextSong  1538173362000
# 13             Boston-Cambridge-Newton, MA-NH    PUT  NextSong  1538331630000
# 14                            Tallahassee, FL    PUT  NextSong  1537365219000
# 15                            Bakersfield, CA    PUT  NextSong  1538173362000
# 16             Boston-Cambridge-Newton, MA-NH    PUT  NextSong  1538331630000
# 17                            Tallahassee, FL    PUT  NextSong  1537365219000
# 18                            Bakersfield, CA    PUT  NextSong  1538173362000
# 19                 Spokane-Spokane Valley, WA    PUT  NextSong  1532482662000
# 20             Boston-Cambridge-Newton, MA-NH    PUT  NextSong  1538331630000
# 21                            Tallahassee, FL    PUT  NextSong  1537365219000
# 22                            Bakersfield, CA    PUT  NextSong  1538173362000
# 23                 Spokane-Spokane Valley, WA    PUT  NextSong  1532482662000
# 24             Boston-Cambridge-Newton, MA-NH    PUT  NextSong  1538331630000
# 25                            Tallahassee, FL    PUT  NextSong  1537365219000
# 26                            Bakersfield, CA    PUT  NextSong  1538173362000
# 27                 Spokane-Spokane Valley, WA    PUT  NextSong  1532482662000
# 28             Boston-Cambridge-Newton, MA-NH    PUT  NextSong  1538331630000
# 29                            Bakersfield, CA    PUT  NextSong  1538173362000
# ...                                       ...    ...       ...            ...
# 228078  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228079  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228080  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228081  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228082  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228083  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228084  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228085  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228086  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228087  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228088  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228089  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228090  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228091  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228092  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228093  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228094  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228095  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228096  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228097  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228098  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228099  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228100  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228101  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228102  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228103  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228104  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228105  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228106  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
# 228107  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1538336771000
#
#         sessionId                                               song  status  \
# 0              29                                          Rockpools     200
# 1               8                                             Canada     200
# 2              29                                  Time For Miracles     200
# 3               8                        Knocking On Forbidden Doors     200
# 4              29                      Harder Better Faster Stronger     200
# 5               8                                     Don't Leave Me     200
# 6               8                                        Run Run Run     200
# 7              29                     Passengers (Old Album Version)     200
# 8              29                                         Fuck Kitty     200
# 9               8                                  Walk On The Water     200
# 10             29                                               Jade     200
# 11              8                                     Gettin' Better     200
# 12             29                                  So-Called Friends     200
# 13              8                                You've Got The Love     200
# 14            217                               Citizens Of Tomorrow     200
# 15             29                                          Represent     200
# 16              8                                             Swisha     200
# 17            217                               Carbon Y Ramas Secas     200
# 18             29                                          Here I Am     200
# 19             53                                        What I Mean     200
# 20              8                                       Sticky Sweet     200
# 21            217                     Sorrow (1997 Digital Remaster)     200
# 22             29                         Rebirthing (Album Version)     200
# 23             53     You'll Never Know (My Love) (Bovellian 07 Mix)     200
# 24              8                                              Smile     200
# 25            217                                         I Want You     200
# 26             29                     Dog Days Are Over (Radio Edit)     200
# 27             53                                            For You     200
# 28              8                                             Closer     200
# 29             29                            Tomorrow Is A Long Time     200
# ...           ...                                                ...     ...
# 228078        500                                       ElÃÂ©ctrico     200
# 228079        500                         Home Is Where The Heart Is     200
Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#         userId
# 0           30
# 1            9
# 2           30
# 3            9
# 4           30
# 5            9
# 6            9
# 7           30
# 8           30
# 9            9
# 10          30
# 11           9
# 12          30
# 13           9
# 14          74
# 15          30
# 16           9
# 17          74
# 18          30
# 19          54
# 20           9
# 21          74
# 22          30
# 23          54
# 24           9
# 25          74
# 26          30
# 27          54
# 28           9
# 29          30
# ...        ...
# 228078  300011
# 228079  300011
# 228080  300011
# 228081  300011
# 228082  300011
# 228083  300011
# 228084  300011
# 228085  300011
# 228086  300011
# 228087  300011
# 228088  300011
# 228089  300011
# 228090  300011
# 228091  300011
# 228092  300011
# 228093  300011
# 228094  300011
# 228095  300011
# 228096  300011
# 228097  300011
# 228098  300011
# 228099  300011
# 228100  300011
# 228101  300011
# 228102  300011
# 228103  300011
# 228104  300011
# 228105  300011
# 228106  300011
# 228107  300011
#
# [228108 rows x 18 columns]

# %% [markdown]
# Null values are found in columns related with user information and song information. We can see that pages that are not NextSong will have null values for artist, length and song.

# %%
df.where(col('firstName').isNull()).toPandas()
# Out:
#      artist        auth firstName gender  itemInSession lastName length level  \
# 0      None  Logged Out      None   None            100     None   None  free
# 1      None  Logged Out      None   None            101     None   None  free
# 2      None  Logged Out      None   None            102     None   None  free
# 3      None  Logged Out      None   None            103     None   None  free
# 4      None  Logged Out      None   None              2     None   None  free
# 5      None  Logged Out      None   None              3     None   None  free
# 6      None  Logged Out      None   None              0     None   None  free
# 7      None  Logged Out      None   None              0     None   None  free
# 8      None  Logged Out      None   None             14     None   None  free
# 9      None  Logged Out      None   None             15     None   None  free
# 10     None  Logged Out      None   None             21     None   None  free
# 11     None  Logged Out      None   None             22     None   None  free
# 12     None  Logged Out      None   None             23     None   None  free
# 13     None  Logged Out      None   None              0     None   None  free
# 14     None  Logged Out      None   None              1     None   None  free
# 15     None  Logged Out      None   None              2     None   None  free
# 16     None  Logged Out      None   None             38     None   None  free
# 17     None  Logged Out      None   None             39     None   None  free
# 18     None  Logged Out      None   None              0     None   None  free
# 19     None  Logged Out      None   None             47     None   None  free
# 20     None  Logged Out      None   None              8     None   None  free
# 21     None  Logged Out      None   None              9     None   None  free
# 22     None  Logged Out      None   None              4     None   None  free
# 23     None  Logged Out      None   None              0     None   None  free
# 24     None  Logged Out      None   None              1     None   None  free
# 25     None  Logged Out      None   None              0     None   None  free
# 26     None  Logged Out      None   None              0     None   None  free
# 27     None  Logged Out      None   None              1     None   None  free
# 28     None  Logged Out      None   None              8     None   None  free
# 29     None  Logged Out      None   None             24     None   None  free
# ...     ...         ...       ...    ...            ...      ...    ...   ...
# 8316   None  Logged Out      None   None             22     None   None  paid
# 8317   None  Logged Out      None   None             23     None   None  paid
# 8318   None  Logged Out      None   None            319     None   None  paid
# 8319   None  Logged Out      None   None            320     None   None  paid
# 8320   None  Logged Out      None   None            385     None   None  paid
# 8321   None  Logged Out      None   None            386     None   None  paid
# 8322   None  Logged Out      None   None            387     None   None  paid
# 8323   None  Logged Out      None   None            126     None   None  paid
# 8324   None  Logged Out      None   None            127     None   None  paid
# 8325   None  Logged Out      None   None             61     None   None  paid
# 8326   None  Logged Out      None   None             62     None   None  paid
# 8327   None  Logged Out      None   None            176     None   None  paid
# 8328   None  Logged Out      None   None            177     None   None  paid
# 8329   None  Logged Out      None   None            247     None   None  paid
# 8330   None  Logged Out      None   None            248     None   None  paid
# 8331   None  Logged Out      None   None            249     None   None  paid
# 8332   None  Logged Out      None   None            278     None   None  paid
# 8333   None  Logged Out      None   None            279     None   None  paid
# 8334   None  Logged Out      None   None            280     None   None  paid
# 8335   None  Logged Out      None   None            336     None   None  paid
# 8336   None  Logged Out      None   None            337     None   None  paid
# 8337   None  Logged Out      None   None             32     None   None  paid
# 8338   None  Logged Out      None   None             33     None   None  paid
# 8339   None  Logged Out      None   None             34     None   None  paid
# 8340   None  Logged Out      None   None              4     None   None  paid
# 8341   None  Logged Out      None   None              5     None   None  paid
# 8342   None  Logged Out      None   None              6     None   None  paid
# 8343   None  Logged Out      None   None             40     None   None  paid
# 8344   None  Logged Out      None   None             41     None   None  paid
# 8345   None  Logged Out      None   None             42     None   None  paid
#
#      location method   page registration  sessionId  song  status  \
# 0        None    GET   Home         None          8  None     200
# 1        None    GET   Help         None          8  None     200
# 2        None    GET   Home         None          8  None     200
# 3        None    PUT  Login         None          8  None     307
# 4        None    GET   Home         None        240  None     200
# 5        None    PUT  Login         None        240  None     307
# 6        None    PUT  Login         None        100  None     307
# 7        None    PUT  Login         None        241  None     307
# 8        None    GET   Home         None        187  None     200
# 9        None    PUT  Login         None        187  None     307
# 10       None    GET   Home         None        187  None     200
# 11       None    GET   Home         None        187  None     200
# 12       None    PUT  Login         None        187  None     307
# 13       None    GET   Home         None         27  None     200
# 14       None    GET  About         None         27  None     200
# 15       None    GET   Home         None         27  None     200
# 16       None    GET   Home         None        187  None     200
# 17       None    PUT  Login         None        187  None     307
# 18       None    GET   Home         None        257  None     200
# 19       None    GET   Home         None        100  None     200
# 20       None    GET   Home         None        255  None     200
# 21       None    PUT  Login         None        255  None     307
# 22       None    GET   Home         None         44  None     200
# 23       None    GET   Home         None        267  None     200
# 24       None    PUT  Login         None        267  None     307
# 25       None    PUT  Login         None         86  None     307
# 26       None    GET   Home         None        266  None     200
# 27       None    PUT  Login         None        266  None     307
# 28       None    GET   Home         None        266  None     200
# 29       None    GET   Home         None        267  None     200
# ...       ...    ...    ...          ...        ...   ...     ...
# 8316     None    GET   Home         None        486  None     200
# 8317     None    PUT  Login         None        486  None     307
# 8318     None    GET   Home         None        482  None     200
# 8319     None    PUT  Login         None        482  None     307
# 8320     None    GET   Home         None        482  None     200
# 8321     None    GET   Help         None        482  None     200
# 8322     None    PUT  Login         None        482  None     307
# 8323     None    GET   Home         None        492  None     200
# 8324     None    PUT  Login         None        492  None     307
# 8325     None    GET   Home         None        488  None     200
# 8326     None    PUT  Login         None        488  None     307
# 8327     None    GET   Home         None        492  None     200
# 8328     None    PUT  Login         None        492  None     307
# 8329     None    GET   Home         None        492  None     200
# 8330     None    GET   Home         None        492  None     200
# 8331     None    PUT  Login         None        492  None     307
# 8332     None    GET   Home         None        492  None     200
# 8333     None    GET   Help         None        492  None     200
# 8334     None    PUT  Login         None        492  None     307
# 8335     None    GET   Home         None        492  None     200
# 8336     None    PUT  Login         None        492  None     307
# 8337     None    GET   Home         None        485  None     200
# 8338     None    GET  About         None        485  None     200
# 8339     None    PUT  Login         None        485  None     307
# 8340     None    GET   Home         None        498  None     200
# 8341     None    GET   Home         None        498  None     200
# 8342     None    PUT  Login         None        498  None     307
# 8343     None    GET   Home         None        500  None     200
# 8344     None    GET   Home         None        500  None     200
# 8345     None    PUT  Login         None        500  None     307
#
#                  ts userAgent userId
# 0     1538355745000      None
# 1     1538355807000      None
# 2     1538355841000      None
# 3     1538355842000      None
# 4     1538356678000      None
# 5     1538356679000      None
# 6     1538358102000      None
# 7     1538360117000      None
# 8     1538361527000      None
# 9     1538361528000      None
# 10    1538362007000      None
# 11    1538362095000      None
# 12    1538362096000      None
# 13    1538363488000      None
# 14    1538363494000      None
# 15    1538363503000      None
# 16    1538364254000      None
# 17    1538364255000      None
# 18    1538364750000      None
# 19    1538370681000      None
# 20    1538373351000      None
# 21    1538373352000      None
# 22    1538373513000      None
# 23    1538375694000      None
# 24    1538375695000      None
# 25    1538376396000      None
# 26    1538377519000      None
# 27    1538377520000      None
# 28    1538378205000      None
# 29    1538379865000      None
# ...             ...       ...    ...
# 8316  1543517274000      None
# 8317  1543517275000      None
# 8318  1543520658000      None
# 8319  1543520659000      None
# 8320  1543532847000      None
# 8321  1543533008000      None
# 8322  1543533009000      None
# 8323  1543537274000      None
# 8324  1543537275000      None
# 8325  1543545102000      None
# 8326  1543545103000      None
# 8327  1543548555000      None
# 8328  1543548556000      None
# 8329  1543565145000      None
# 8330  1543565368000      None
# 8331  1543565369000      None
# 8332  1543572656000      None
# 8333  1543572774000      None
# 8334  1543572775000      None
# 8335  1543586425000      None
# 8336  1543586426000      None
# 8337  1543604143000      None
# 8338  1543604164000      None
# 8339  1543604165000      None
# 8340  1543604533000      None
# 8341  1543604776000      None
# 8342  1543604777000      None
# 8343  1543622135000      None
# 8344  1543622240000      None
# 8345  1543622241000      None
#
# [8346 rows x 18 columns]

# %% [markdown]
# We can see that users with missing user information did not register and log in.

# %%
df.where(col('firstName').isNull()).groupBy('registration', 'auth').count().toPandas()
# Out:
#   registration        auth  count
# 0         None  Logged Out   8249
# 1         None       Guest     97

# %% [markdown]
# Since logs with empty/missing userId can’t help us identify the users, we can’t make predictions for them. So we drop them from our analysis.

# %%
df = df.where(col('firstName').isNotNull())
df.count()
# Out:
# 278154

# %%
# correlation between various features , using a sample of data
sample_user_log = df.sample(withReplacement=False, fraction=0.1).toPandas()
sample_user_log = sample_user_log.select_dtypes(include=['int64','float64'])
sample_user_log = sample_user_log.dropna()
sns.pairplot(sample_user_log)

# %% [markdown]
# From the pairplot above, we can observe that there are a number of correlated features : ts and sessionId.

# %% [markdown]
# ### Define Churn
#
# Before we can move on to comparing users who churned and those who did not, we first need to think about what we would define as churne. A narrow definition would probably only include people who have deleted their account， which is captured in our data as cases where the page feature takes on the value "Cancellation Confirmation".
#
# If we take on a broader view, we could also think of users downgrading their services from paid to free as a type of churning. It turns out that identifying these users is a bit more complicated. While a user can only cancel their registration once, it is very much possible for a customer to downgrade from the paid to the free service and to then upgrade to the paid service again or to even repeat this cycle.
#
# The question then is whether these two kinds of churning should be regarded as identical or whether we should really think of this as a multiclass-classification problem instead of a binary classification problem. Ideally, we should conduct a survey with users who canceled their registration and those who only switched from the paid to the free version of the service to gain some insights as to whether they are similar or quite different. This is unfortunately not possible for this project.
#
# Looking at the available data, it turns out that if we also include users who just downgraded their accounts from paid to free, but still kept using the service many differences between the two groups of users become much less clear cut. Therefore, I decided to only include users who canceled their services here.
#
# Finally, strictly speaking defining churn by just accounting for users who have canceled their account will quite likely underestimate actual churn rates. There may be users who perhaps never used the paid service and who stopped using the service, but never bothered to cancel their registration. Given that the data we have here only covers about two months, it is probably not reasonable to try to cover this problem, but it is certainly a point worth keeping in mind.
#
# We will use the Cancellation Confirmation event of pages to define churn. Churned users will have a 1 in the column churn, the label column for our model.

# %%
user_log = df

flag_churn = udf(lambda x: 1 if x == 'Cancellation Confirmation' else 0, IntegerType())
user_log = user_log.withColumn('cancel_page',flag_churn('page'))

windowval = Window.partitionBy('userId')
user_log = user_log.withColumn('churned',Fsum('cancel_page').over(windowval))

# %%
print('Number of users who have churned {}'.\
      format(user_log.filter(user_log.churned == 1).select('userId').dropDuplicates().count()))
print('Number of users who have not churned {}'.\
      format(user_log.filter(user_log.churned == 0).select('userId').dropDuplicates().count()))
# Out:
# Number of users who have churned 52
# Number of users who have not churned 173

# %%
#percent of churned users
user_log.filter(user_log['churned']==1).select('userId').distinct().count()/user_log.select('userId')\
        .distinct().count()
# Out:
# 0.2311111111111111

# %% [markdown]
# We can see that the two labels (churn and non-churn) of the dataset are inbalanced.

# %% [markdown]
# #### Gender distribution

# %%
gender_churn = user_log.select(["userId","gender", "churned"]).dropDuplicates().\
                    groupby(["churned"]).pivot("gender").agg(count("userId")).toPandas()
gender_churn
# Out:
#    churned   F   M
# 0        0  84  89
# 1        1  20  32

# %%
total_user_f = user_log[user_log["gender"] == 'F'].select("userId").distinct().count()
total_user_m = user_log[user_log["gender"] == 'M'].select("userId").distinct().count()
female_pct = gender_churn[gender_churn['churned'] == 1]['F'] / total_user_f *100
male_pct = gender_churn[gender_churn['churned'] == 1]['M'] / total_user_m * 100

print("there were %d percent female users churned" % female_pct)
print("there were %d percent male users churned" % male_pct)
# Out:
# there were 19 percent female users churned
# there were 26 percent male users churned

# %%
# Visualising churn counts by level of Users
level_churn_df = user_log.select('userId','level','churned').dropDuplicates().toPandas()
sns.countplot(x='level',hue='churned',data=level_churn_df)
plt.xlabel("Level of User")
plt.ylabel("Number of Users")
plt.title("Count of Churned Users by levels")
# Out:
# Text(0.5,1,'Count of Churned Users by levels')

# %%
free_churned = len(level_churn_df[(level_churn_df['churned'] == 1) & (level_churn_df['level'] == 'free')]) / len(level_churn_df[level_churn_df['level'] == 'free']) * 100
paid_churned = len(level_churn_df[(level_churn_df['churned'] == 1) & (level_churn_df['level'] == 'paid')])/ len(level_churn_df[level_churn_df['level'] == 'paid']) * 100

print("there were %d percent free users churned" % free_churned)
print("there were %d percent paid users churned" % paid_churned)
# Out:
# there were 23 percent free users churned
# there were 21 percent paid users churned

# %%
# pivot table displaying number of page events per user
df_page = user_log.groupby("userId","churned").pivot("page").count().fillna(0).toPandas()
df_page.head()
# Out:
#    userId  churned  About  Add Friend  Add to Playlist  Cancel  \
# 0  100010        0      1           4                7       0
# 1  200002        0      3           4                8       0
# 2     125        1      0           0                0       1
# 3     124        0      7          74              118       0
# 4      51        1      2          28               52       1
#
#    Cancellation Confirmation  Downgrade  Error  Help   ...     Logout  \
# 0                          0          0      0     2   ...          5
# 1                          0          5      0     2   ...          5
# 2                          1          0      0     0   ...          0
# 3                          0         41      6    23   ...         59
# 4                          1         23      1    12   ...         24
#
#    NextSong  Roll Advert  Save Settings  Settings  Submit Downgrade  \
# 0       275           52              0         0                 0
# 1       387            7              0         3                 0
# 2         8            1              0         0                 0
# 3      4079            4              6        20                 0
# 4      2111            0              1        12                 0
#
#    Submit Upgrade  Thumbs Down  Thumbs Up  Upgrade
# 0               0            5         17        2
# 1               1            6         21        2
# 2               0            0          0        0
# 3               0           41        171        0
# 4               0           21        100        0
#
# [5 rows x 21 columns]

# %%
# Boxplot grouped by Cancellation Confirmation
fig= plt.figure(figsize = (15, 20))

for i in range(1,21):
    ax = fig.add_subplot(4, 6, i)
    df_page.boxplot(df_page.columns[i].format(), ax=ax,  by='Cancellation Confirmation', grid=False, showfliers=False);

# %% [markdown]
# From above boxplots, we can see difference in between the two groups of churned and non-churned users. In generally, churned users have added less friends, added lesser songs to playlist, witnessed lesser errors(which could be due to lesser engagement), given lesser thumbs up, thumbs down , asked for less help and listened to less songs. We can therefore utilize these observations when creating features for our model.

# %%
#Time spent by users of both groups listening to songs
user_log.where(user_log["page"] == "NextSong").select("userId","churned","length")\
                        .groupby("userId","churned").agg({"length":"sum"})\
                        .groupby("churned")\
                        .agg({"sum(length)":"avg"})\
                        .withColumnRenamed("avg(sum(length))", "Average_time").toPandas()
# Out:
#    churned   Average_time
# 0        0  276166.937468
# 1        1  174014.268551

# %%
# number of thumbs up
user_log.select("userId", "page","churned").where(user_log["page"]=="Thumbs Up")\
                .groupby("userId","churned").agg({"page":"count"}) \
                .groupby("churned")\
                .agg({"count(page)":"avg"})\
                .withColumnRenamed("avg(count(page))","Average_num_Thumbs_up").toPandas()
# Out:
#    churned  Average_num_Thumbs_up
# 0        0              62.894118
# 1        1              37.180000

# %%
# number of thumbs down
user_log.select("userId", "page","churned").where(user_log["page"]=="Thumbs Down")\
                .groupby("userId","churned").agg({"page":"count"}) \
                .groupby("churned")\
                .agg({"count(page)":"avg"})\
                .withColumnRenamed("avg(count(page))", "Average_num_Thumbs_down").toPandas()
# Out:
#    churned  Average_num_Thumbs_down
# 0        0                13.225806
# 1        1                10.333333

# %%
# number of songs played
user_log.select("userId","song","churned")\
                .groupby("userId","churned").agg({"song":"count"})\
                .groupby("churned")\
                .agg({"count(song)":"avg"})\
                .withColumnRenamed("avg(count(song))", "average_num_songs").toPandas()
# Out:
#    churned  average_num_songs
# 0        0        1108.173410
# 1        1         699.884615

# %%
# Number of songs listened per session per user
user_log.filter(user_log["page"]=="NextSong")\
                .groupby("userId","sessionId").agg({"sessionId":"count"})\
                .groupby("userId")\
                .agg({"count(sessionId)":"avg"})\
                .withColumnRenamed("avg(count(sessionId))","songsPerSession").toPandas()
# Out:
#      userId  songsPerSession
# 0    100010        39.285714
# 1    200002        64.500000
# 2       125         8.000000
# 3        51       211.100000
# 4       124       145.678571
# 5         7        21.428571
# 6        54        81.171429
# 7        15       136.714286
# 8       155       136.666667
# 9    100014        42.833333
# 10      132       120.500000
# 11      154        28.000000
# 12      101       179.700000
# 13       11        40.437500
# 14   300017        59.540984
# 15      138       138.000000
# 16       29        89.058824
# 17       69       125.000000
# 18   100021        46.000000
# 19       42        87.146341
# 20      112        23.888889
# 21       87        30.680000
# 22       73        62.833333
# 23   200010        39.500000
# 24       64        15.333333
# 25        3        53.500000
# 26      113        68.913043
# 27       30        50.607143
# 28       34        17.666667
# 29      133        32.000000
# ..      ...              ...
# 195      83        45.740741
# 196     123        18.750000
# 197     109        59.750000
# 198  200022        43.500000
# 199      13        38.787879
# 200  200019        49.500000
# 201      14       111.818182
# 202      21       124.750000
# 203      66        52.250000
# 204      94        24.333333
# 205      91       286.666667
# 206     137        51.333333
# 207      74       109.090909
# 208      72        85.000000
# 209  300016        48.583333
# 210  200015        25.800000
# 211     151       138.000000
# 212     129        55.166667
# 213      76        35.333333
# 214       2       107.857143
# 215      80        30.583333
# 216  100018        50.100000
# 217  100002        48.750000
# 218      50        62.875000
# 219     145        80.642857
# 220      45        98.933333
# 221      57        46.000000
# 222  200021        76.687500
# 223     119        28.833333
# 224  100001        33.250000
#
# [225 rows x 2 columns]

# %%
# number of days since registration
user_log.select("userId","churned","registration","ts")\
                .withColumn("timeSinceReg", (user_log["ts"]-user_log["registration"]))\
                .groupby("userId", "churned")\
                .agg({"timeSinceReg": "max"})\
                .withColumnRenamed("max(timeSinceReg)","active_days")\
                .select("userId","churned",(col("active_days")/1000/3600/24).alias("active_days"))\
                .groupby("churned")\
                .agg({"active_days":"avg"}).withColumnRenamed("avg(active_days)", "avg_num_of_active_days").toPandas()
# Out:
#    churned  avg_num_of_active_days
# 0        0               86.620619
# 1        1               57.305993

# %%
# number of added friends
user_log.select("userId", "page","churned")\
        .where(user_log["page"]=="Add Friend")\
        .groupby("userId","churned")\
        .agg({"page": "count"})\
        .groupby("churned")\
        .agg({"count(page)":"avg"}).withColumnRenamed("avg(count(page))", "avg_num_of_added_friends")\
        .toPandas()
# Out:
#    churned  avg_num_of_added_friends
# 0        0                 22.475309
# 1        1                 14.454545

# %% [markdown]
# # Feature Engineering
#
# Now we are familiarized with the data, let's build the features we find promising to train the model on.

# %%
user_log = user_log.withColumn('last_level', F.last('level').over(windowval))

# %%
f1 = user_log.select("userId", "length").groupby("userId").agg({"length":"sum"}).withColumnRenamed("sum(length)","playTime")
f1.show()
# Out:
# +------+------------------+
# |userId|          playTime|
# +------+------------------+
# |100010| 66940.89735000003|
# |200002| 94008.87593999993|
# |   125|2089.1131000000005|
# |    51| 523275.8428000004|
# |   124|1012312.0927899999|
# |     7| 38034.08710000002|
# |    54| 711344.9195400011|
# |    15|477307.60581000015|
# |   155|       198779.2919|
# |   132| 483118.9038399997|
# |   154|20660.023910000007|
# |100014| 67703.47208000004|
# |   101| 447464.0146699989|
# |    11|159669.96303999983|
# |   138| 512449.8827599989|
# |300017| 897406.9802100015|
# |    29| 754517.5625700009|
# |    69| 286064.0256399999|
# |100021| 57633.17563999999|
# |    42| 881792.9661300007|
# +------+------------------+
# only showing top 20 rows

# %%
f2 = user_log.select("userId","song")\
                .groupby("userId").agg({"song":"count"}).withColumnRenamed("count(song)", "numSongs")
f2.show()
# Out:
# +------+--------+
# |userId|numSongs|
# +------+--------+
# |100010|     275|
# |200002|     387|
# |   125|       8|
# |    51|    2111|
# |   124|    4079|
# |     7|     150|
# |    54|    2841|
# |    15|    1914|
# |   155|     820|
# |   132|    1928|
# |   154|      84|
# |100014|     257|
# |   101|    1797|
# |    11|     647|
# |   138|    2070|
# |300017|    3632|
# |    29|    3028|
# |    69|    1125|
# |100021|     230|
# |    42|    3573|
# +------+--------+
# only showing top 20 rows

# %%
f3 = user_log.select("userId","artist")\
                .groupby("userId").agg(F.countDistinct("artist")).withColumnRenamed("count(DISTINCT artist)", "numArtist")
f3.show()
# Out:
# +------+---------+
# |userId|numArtist|
# +------+---------+
# |100010|      252|
# |200002|      339|
# |   125|        8|
# |    51|     1385|
# |   124|     2232|
# |     7|      142|
# |    15|     1302|
# |    54|     1744|
# |   155|      643|
# |   132|     1299|
# |   154|       78|
# |100014|      233|
# |   101|     1241|
# |    11|      534|
# |   138|     1332|
# |300017|     2070|
# |    29|     1804|
# |    69|      865|
# |100021|      207|
# |    42|     2073|
# +------+---------+
# only showing top 20 rows

# %%
f4 = user_log.select("userId","registration","ts")\
                .withColumn("timeSinceReg", (user_log["ts"]-user_log["registration"]))\
                .groupby("userId")\
                .agg({"timeSinceReg": "max"})\
                .withColumnRenamed("max(timeSinceReg)","active_days")\
                .select("userId",(col("active_days")/1000/3600/24).alias("active_days"))
f4.show()
# Out:
# +------+------------------+
# |userId|       active_days|
# +------+------------------+
# |100010|  55.6436574074074|
# |200002| 70.07462962962963|
# |   125| 71.31688657407408|
# |    51|19.455844907407407|
# |   124|131.55591435185184|
# |     7| 72.77818287037037|
# |    54|110.75168981481481|
# |    15|56.513576388888886|
# |   155|23.556018518518517|
# |   132|  66.8891087962963|
# |   154|23.872037037037035|
# |100014| 85.08340277777778|
# |   101|53.965937499999995|
# |    11|124.47825231481481|
# |   138| 66.62668981481481|
# |300017| 74.35851851851852|
# |    29|60.104050925925925|
# |    69| 71.42444444444445|
# |100021| 64.73886574074074|
# |    42| 67.11364583333334|
# +------+------------------+
# only showing top 20 rows

# %%
f5 = user_log.select("userId","sessionId")\
                .groupby("userId").agg(F.countDistinct("sessionId")).withColumnRenamed("count(DISTINCT sessionId)", "numSession")
f5.show()
# Out:
# +------+----------+
# |userId|numSession|
# +------+----------+
# |100010|         7|
# |200002|         6|
# |   125|         1|
# |    51|        10|
# |   124|        29|
# |     7|         7|
# |    54|        37|
# |    15|        15|
# |   155|         6|
# |100014|         6|
# |   132|        16|
# |   154|         3|
# |   101|        10|
# |    11|        16|
# |300017|        63|
# |   138|        15|
# |    29|        34|
# |    69|         9|
# |100021|         5|
# |    42|        47|
# +------+----------+
# only showing top 20 rows

# %%
#encode level and gender
indexer = StringIndexer(inputCol="last_level", outputCol="encoded_level")
user_log = indexer.fit(user_log).transform(user_log)

indexer1 = StringIndexer(inputCol="gender", outputCol="encoded_gender")
user_log = indexer1.fit(user_log).transform(user_log)

# %%
user_features = user_log.select("userId", "encoded_level", "encoded_gender").dropDuplicates()

f6 = user_features.select("userId","encoded_level")\
        .groupby("userId")\
        .agg({"encoded_level": "max"}).withColumnRenamed("max(encoded_level)", "encoded_level")

# %%
f7 = user_features.select("userId","encoded_gender")\
        .groupby("userId")\
        .agg({"encoded_gender": "max"}).withColumnRenamed("max(encoded_gender)", "encoded_gender")

# %%
user_df = user_log.groupby('userId').agg(
    # User-level features
    F.max('churned').alias('churn'),

    # interaction-level features (exclude Cancellation Confirmation)
    F.count('page').alias('n_act'),
    F.sum(F.when(F.col('page')=='About', 1).otherwise(0)).alias('n_about'),
    F.sum(F.when(F.col('page')=='Add Friend', 1).otherwise(0)).alias('n_addFriend'),
    F.sum(F.when(F.col('page')=='Add to Playlist', 1).otherwise(0)).alias('n_addToPlaylist'),
    F.sum(F.when(F.col('page')=='Cancel', 1).otherwise(0)).alias('n_cancel'),
    F.sum(F.when(F.col('page')=='Downgrade', 1).otherwise(0)).alias('n_downgrade'),
    F.sum(F.when(F.col('page')=='Error', 1).otherwise(0)).alias('n_error'),
    F.sum(F.when(F.col('page')=='Help', 1).otherwise(0)).alias('n_help'),
    F.sum(F.when(F.col('page')=='Home', 1).otherwise(0)).alias('n_home'),
    F.sum(F.when(F.col('page')=='Logout', 1).otherwise(0)).alias('n_logout'),
    F.sum(F.when(F.col('page')=='Roll Advert', 1).otherwise(0)).alias('n_rollAdvert'),
    F.sum(F.when(F.col('page')=='Save Settings', 1).otherwise(0)).alias('n_saveSettings'),
    F.sum(F.when(F.col('page')=='Settings', 1).otherwise(0)).alias('n_settings'),
    F.sum(F.when(F.col('page')=='Submit Downgrade', 1).otherwise(0)).alias('n_submitDowngrade'),
    F.sum(F.when(F.col('page')=='Submit Upgrade', 1).otherwise(0)).alias('n_submitUpgrade'),
    F.sum(F.when(F.col('page')=='Thumbs Down', 1).otherwise(0)).alias('n_thumbsDown'),
    F.sum(F.when(F.col('page')=='Thumbs Up', 1).otherwise(0)).alias('n_thumbsUp'),
    F.sum(F.when(F.col('page')=='Upgrade', 1).otherwise(0)).alias('n_upgrade'),

)

# %%
user_df = user_df.join(f1, on = "userId")\
           .join(f2, on = "userId")\
           .join(f3, on = "userId")\
           .join(f4, on = "userId")\
           .join(f5, on = "userId")\
           .join(f6, on = "userId")\
           .join(f7, on = "userId")
            
user_df.toPandas()
# Out:
#      userId  churn  n_act  n_about  n_addFriend  n_addToPlaylist  n_cancel  \
# 0    100010      0    381        1            4                7         0
# 1    200002      0    474        3            4                8         0
# 2       125      1     11        0            0                0         1
# 3       124      0   4825        7           74              118         0
#  |-- userId: string (nullable = true)
#  |-- churn: long (nullable = true)
#  |-- n_act: long (nullable = false)
#  |-- n_about: long (nullable = true)
#  |-- n_addFriend: long (nullable = true)
#  |-- n_addToPlaylist: long (nullable = true)
#  |-- n_cancel: long (nullable = true)
#  |-- n_downgrade: long (nullable = true)
#  |-- n_error: long (nullable = true)
#  |-- n_help: long (nullable = true)
#  |-- n_home: long (nullable = true)
#  |-- n_logout: long (nullable = true)
#  |-- n_rollAdvert: long (nullable = true)
#  |-- n_saveSettings: long (nullable = true)
#  |-- n_settings: long (nullable = true)
#  |-- n_submitDowngrade: long (nullable = true)
#  |-- n_submitUpgrade: long (nullable = true)
#  |-- n_thumbsDown: long (nullable = true)
#  |-- n_thumbsUp: long (nullable = true)
#  |-- n_upgrade: long (nullable = true)
#  |-- playTime: double (nullable = true)
#  |-- numSongs: long (nullable = false)
#  |-- numArtist: long (nullable = false)
#  |-- active_days: double (nullable = true)
#  |-- numSession: long (nullable = false)
#  |-- encoded_level: double (nullable = true)
#  |-- encoded_gender: double (nullable = true)

# %% [markdown]
# #### Correlations among Features

# %%
user_pd = user_df.toPandas()
user_pd.shape
# Out:
# (225, 27)

# %% [markdown]
# Multicollinearity increases the standard errors of the coefficients. Increased standard errors in turn means that coefficients for some independent variables may be found not to be significantly different from 0. In other words, by overinflating the standard errors, multicollinearity makes some variables statistically insignificant when they should be significant. Without multicollinearity (and thus, with lower standard errors), those coefficients might be significant.

# %%
def plot_corr(cols, figsize=(10,10), filename=None, df=user_pd):
    """ 
    This function plots correlations amoung columns 
  
     Parameters: 
        cols: Columns to be plotted
        figsize: Size of the figure
        filename: File name of the figure being saved
        df: The dataframe which contains the columns
          
    Returns: 
        A heatmap & correlation matrics of imputed columns
    """
    plt.figure(figsize=figsize)
    sns.heatmap(df[cols].corr(),
                square=True, cmap='YlGnBu', annot=True,
                vmin=-1, vmax=1)
    plt.ylim(len(cols), 0)
    if filename:
        plt.savefig(filename)
    plt.show();

# %%
# correlations between features
numerical_cols = user_pd.select_dtypes(include=np.number).columns.tolist()
plot_corr(numerical_cols, figsize=(20,20), filename='corr_full.png')

# %% [markdown]
# We can see that there are some variable pairs with correlation coefficient over 0.8, which means that many of our variables are highly corelated. in order to remove the multicollinearity, let's try a few approaches:
#
# - Remove correlated features manually
#
# - PCA

# %% [markdown]
# #### 1. Remove correlated feature manually:

# %%
cols = ['n_act', 'n_addFriend', 'n_addToPlaylist', 'n_downgrade',
        'n_help', 'n_home', 'n_thumbsUp','n_logout','playTime', 'n_thumbsDown', 'numSession','numSongs',
        'numArtist']
plot_corr(cols, filename='corr_n_event.png')

# %%
# correlations between numerical features after removing highly correlated columns
drop_cols = ['n_act', 'n_addFriend', 'n_addToPlaylist', 'n_downgrade',
        'n_help', 'n_home', 'n_thumbsUp','n_logout', 'playTime', 'n_cancel','numSongs','numArtist']
numerical_cols1 = [col for col in user_pd.columns if col not in drop_cols]
plot_corr(numerical_cols1, figsize=(20,20))

# %%
user_df_m = user_df.select(*numerical_cols1).withColumnRenamed('churned', 'label')
user_df_m.persist();
user_df_m.printSchema()
# Out:
# root
#  |-- userId: string (nullable = true)
#  |-- churn: long (nullable = true)
#  |-- n_about: long (nullable = true)
#  |-- n_error: long (nullable = true)
#  |-- n_rollAdvert: long (nullable = true)
#  |-- n_saveSettings: long (nullable = true)
#  |-- n_settings: long (nullable = true)
#  |-- n_submitDowngrade: long (nullable = true)
#  |-- n_submitUpgrade: long (nullable = true)
#  |-- n_thumbsDown: long (nullable = true)
#  |-- n_upgrade: long (nullable = true)
#  |-- active_days: double (nullable = true)
#  |-- numSession: long (nullable = false)
#  |-- encoded_level: double (nullable = true)
#  |-- encoded_gender: double (nullable = true)

# %%
# Vector Assembler
cols = user_df_m.drop('userId','churn').columns
assembler = VectorAssembler(inputCols=cols, outputCol='Features')
user_df_m = assembler.transform(user_df_m)

# %%
# Standard Scaler
scaler= FT.StandardScaler(inputCol='Features', outputCol='scaled_features_1', withStd=True)
scalerModel = scaler.fit(user_df_m)
user_df_m = scalerModel.transform(user_df_m)

# %%
user_df_m.persist();
user_df_m.printSchema()
# Out:
# root
#  |-- userId: string (nullable = true)
#  |-- churn: long (nullable = true)
#  |-- n_about: long (nullable = true)
#  |-- n_error: long (nullable = true)
#  |-- n_rollAdvert: long (nullable = true)
#  |-- n_saveSettings: long (nullable = true)
#  |-- n_settings: long (nullable = true)
#  |-- n_submitDowngrade: long (nullable = true)
#  |-- n_submitUpgrade: long (nullable = true)
#  |-- n_thumbsDown: long (nullable = true)
#  |-- n_upgrade: long (nullable = true)
#  |-- active_days: double (nullable = true)
#  |-- numSession: long (nullable = false)
#  |-- encoded_level: double (nullable = true)
#  |-- encoded_gender: double (nullable = true)
#  |-- Features: vector (nullable = true)
#  |-- scaled_features_1: vector (nullable = true)

# %%
# selecting the two required columns for modelling
m_features_df = user_df_m.select(col('scaled_features_1').alias('features'), col('churn').alias('label'))
m_features_df
# Out:
# DataFrame[features: vector, label: bigint]

# %% [markdown]
# #### PCA
#
# Principal component analysis (PCA) is a statistical analysis technique that transforms possibly correlated variables to orthogonal linearly uncorrelated values. We can use it for applications such as data compression, to get dominant physical processes and to get important features for machine learning. Without losing much information, it reduces the number of features in the original data.

# %%
# Vector Assembler
user_df_pca = user_df
cols = user_df_pca.drop('userId','churn').columns
assembler = VectorAssembler(inputCols=cols, outputCol='Features')
user_df_pca = assembler.transform(user_df).select('userId', 'churn','Features')

# Standard Scaler
scaler= FT.StandardScaler(inputCol='Features', outputCol='scaled_features_1', withStd=True)
scalerModel = scaler.fit(user_df_pca)
user_df_pca = scalerModel.transform(user_df_pca)
user_df_pca.select(['userId','churn', 'scaled_features_1']).show(5, truncate = False)
# Out:
# +------+-----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |userId|churn|scaled_features_1                                                                                                                                                                                                                                                                                                                                                                                                    |
# +------+-----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# n_submitUpgrade   -0.043323 -0.232013 -0.172380 -0.041573
# n_thumbsDown      -0.015296  0.021667  0.047702  0.101978
# n_thumbsUp        -0.080941  0.172037 -0.099635 -0.032521
# n_upgrade          0.221255  0.176430  0.307313 -0.197514
# playTime          -0.046256  0.057663 -0.021154  0.096822
# numSongs          -0.048032  0.057638 -0.020282  0.095627
# numArtist         -0.025874  0.022971 -0.000238  0.099777
# active_days       -0.121668  0.357218 -0.140792 -0.120499
# numSession         0.052818  0.158798  0.064081 -0.036856
# encoded_level     -0.231384 -0.016792 -0.138716 -0.054442
# encoded_gender     0.038227  0.099769  0.003853 -0.028856

# %%
pca_result.persist();
pca_result.printSchema()
# Out:
# root
#  |-- userId: string (nullable = true)
#  |-- churn: long (nullable = true)
#  |-- pcaFeatures: vector (nullable = true)

# %%
# selecting the two required columns for modelling
pca_features_df = pca_result.select(col('pcaFeatures').alias('features'), col('churn').alias('label'))
pca_features_df

pca_features_df.persist();
pca_features_df.printSchema()
# Out:
# root
#  |-- features: vector (nullable = true)
#  |-- label: long (nullable = true)

# %%
pca_features_df.limit(2).toPandas()
# Out:
#                                             features  label
# 0  [-1.1734398241, -2.15707206925, -0.64948661817...      0
# 1  [-1.79716505228, -0.543570606376, -0.761087008...      0

# %% [markdown]
# # Modeling
#
# #### Split Data into Train and Test sets
# From the distribution of churn shown in the previous session, we know that this is an unbalanced dataset with only 1/4 of users labeled as churn. To avoid unbalanced results in random split, we first make a train set with sampling by label, then subtract them from the whole dataset to get the test set.

# %%
# prepare training and test data, sample by label
ratio = 0.7
train_m = m_features_df.sampleBy('churn', fractions={0:ratio, 1:ratio}, seed=123)
test_m = m_features_df.subtract(train_m)

# %%
train_pca = pca_features_df.sampleBy('churn', fractions={0:ratio, 1:ratio}, seed=123)
test_pca = pca_features_df.subtract(train_pca)

# %% [markdown]
# #### Model Selection
# In order to select a good model for the final tuning, we will compare four different classifier models in Spark's ML:
#
# - Logistic Regression
# - Decision Tree
# - Random Forest

# %% [markdown]
# ##### Logistic Regression

# %%
# initialize classifier
lr = LogisticRegression(maxIter=10)

# evaluator
evaluator_1 = MulticlassClassificationEvaluator(metricName='f1')

# paramGrid
paramGrid = ParamGridBuilder() \
    .build()

crossval_lr = CrossValidator(estimator=lr,
                          evaluator=evaluator_1, 
                          estimatorParamMaps=paramGrid,
                          numFolds=3)

# %%
cvModel_lr_pca = crossval_lr.fit(train_pca)
cvModel_lr_m = crossval_lr.fit(train_m)
print(cvModel_lr_pca.avgMetrics)
print(cvModel_lr_m.avgMetrics)
# Out:
# [1.0]
# [0.7478355104947378]

# %%
results_lr_m = cvModel_lr_m.transform(test_m)
results_lr_pca = cvModel_lr_pca.transform(test_pca)
evaluator = evaluator= MulticlassClassificationEvaluator(predictionCol='prediction')

print("F1 score of Logistic Regression Model with manual dimension reduction is: ")
print(evaluator.evaluate(results_lr_m, {evaluator.metricName: "f1"}))
print("F1 score of Logistic Regression Model with PCA is: ")
print(evaluator.evaluate(results_lr_pca, {evaluator.metricName: "f1"}))

print("Accuracy of Logistic Regression Model of manual dimension reduction is: ")
print(evaluator.evaluate(results_lr_m, {evaluator.metricName: "accuracy"}))
print("Accuracy of Logistic Regression Model is: ")
print(evaluator.evaluate(results_lr_pca, {evaluator.metricName: "accuracy"}))
# Out:
# F1 score of Logistic Regression Model with manual dimension reduction is:
# 0.7751861042183624
# F1 score of Logistic Regression Model with PCA is:
# 1.0
# Accuracy of Logistic Regression Model of manual dimension reduction is:
# 0.8064516129032258
# Accuracy of Logistic Regression Model is:
# 1.0

# %% [markdown]
# #### Decision tree classifier

# %%
# initialize classifier
dtc = DecisionTreeClassifier()

# evaluator
evaluator_2 = MulticlassClassificationEvaluator(metricName='f1')

# paramGrid
paramGrid = ParamGridBuilder() \
    .build()

crossval_dtc = CrossValidator(estimator=dtc,
                          evaluator=evaluator_2, 
                          estimatorParamMaps=paramGrid,
                          numFolds=3)

# %%
cvModel_dtc_m = crossval_dtc.fit(train_m)
cvModel_dtc_pca = crossval_dtc.fit(train_pca)
print(cvModel_dtc_m.avgMetrics)
print(cvModel_dtc_pca.avgMetrics)
# Out:
# [0.779086895142047]
# [0.9453949700767756]

# %%
results_dtc_m = cvModel_dtc_m.transform(test_m)
results_dtc_pca = cvModel_dtc_pca.transform(test_pca)
evaluator = MulticlassClassificationEvaluator(predictionCol='prediction')

print("F1 score of Decision Tree Classifier Model with manual dimension reduction is: ")
print(evaluator.evaluate(results_dtc_m, {evaluator.metricName: "f1"}))
print("F1 score of Decision Tree Classifier Model with PCA is: ")
print(evaluator.evaluate(results_dtc_pca, {evaluator.metricName: "f1"}))

print("Accuracy of Decision Tree Classifier Model with manual dimension reduction is: ")
print(evaluator.evaluate(results_dtc_m, {evaluator.metricName: "accuracy"}))
print("Accuracy of Decision Tree Classifier Model with PCA is: ")
print(evaluator.evaluate(results_dtc_pca, {evaluator.metricName: "accuracy"}))
# Out:
# F1 score of Decision Tree Classifier Model with manual dimension reduction is:
# 0.7221421621155576
# F1 score of Decision Tree Classifier Model with PCA is:
# 0.8925483119031505
# Accuracy of Decision Tree Classifier Model with manual dimension reduction is:
# 0.7258064516129032
# Accuracy of Decision Tree Classifier Model with PCA is:
# 0.8870967741935484

# %% [markdown]
# #### Random Forest Classifier

# %%
# initialize classifier
rfc = RandomForestClassifier()

# evaluator
evaluator_3 = MulticlassClassificationEvaluator(metricName='f1')

# paramGrid
paramGrid = ParamGridBuilder() \
    .build()

crossval_rfc = CrossValidator(estimator=rfc,
                          evaluator=evaluator_3, 
                          estimatorParamMaps=paramGrid,
                          numFolds=3)

# %%
cvModel_rfc_m = crossval_rfc.fit(train_m)
cvModel_rfc_pca = crossval_rfc.fit(train_pca)
print(cvModel_rfc_m.avgMetrics)
print(cvModel_rfc_pca.avgMetrics)
# Out:
# [0.8362662175971391]
# [0.9696354720179988]

# %%
results_rfc_m = cvModel_rfc_m.transform(test_m)
results_rfc_pca = cvModel_rfc_pca.transform(test_pca)

evaluator = MulticlassClassificationEvaluator(predictionCol='prediction')
print("F1 score of Random Forest Classifier Model with manual dimension reduction is: ")
print(evaluator.evaluate(results_rfc_m, {evaluator.metricName: "f1"}))
print("F1 score of Random Forest Classifier Model with PCA is: ")
print(evaluator.evaluate(results_rfc_pca, {evaluator.metricName: "f1"}))

print("Accuracy of Random Forest Classifier Model with manual dimension reduction: ")
print(evaluator.evaluate(results_rfc_m, {evaluator.metricName: "accuracy"}))
print("Accuracy of Random Forest Classifier Model with PCA is: ")
print(evaluator.evaluate(results_rfc_pca, {evaluator.metricName: "accuracy"}))
# Out:
# F1 score of Random Forest Classifier Model with manual dimension reduction is:
# 0.714335000862515
# F1 score of Random Forest Classifier Model with PCA is:
# 0.967741935483871
# Accuracy of Random Forest Classifier Model with manual dimension reduction:
# 0.7419354838709677
# Accuracy of Random Forest Classifier Model with PCA is:
# 0.967741935483871

# %% [markdown]
# #### Refinement and Hyperparameter tuning
# I use 3 parameters for tuning the Random Forest model : maxDepth, minInstancesPerNode and numTress

# %%
paramGrid_rfc_final= ParamGridBuilder()\
    .addGrid(rfc.maxDepth, [5, 8])\
    .addGrid(rfc.minInstancesPerNode,[1,4])\
    .addGrid(rfc.numTrees,[20,40])\
    .build()

crossval_rfc_final = CrossValidator(estimator=rfc,
                          estimatorParamMaps=paramGrid_rfc_final,
                          evaluator=MulticlassClassificationEvaluator(metricName='f1'),
                          numFolds=3)

# %%
cvModel_rfc_final = crossval_rfc_final.fit(train_pca)

# %%
# The best parameters for the model are
print("maxDepth", cvModel_rfc_final.bestModel._java_obj.getMaxDepth())
print("minInstancesPerNode", cvModel_rfc_final.bestModel._java_obj.getMinInstancesPerNode())
print("numTrees", cvModel_rfc_final.bestModel._java_obj.getNumTrees())
# Out:
# maxDepth 5
# minInstancesPerNode 1
# numTrees 40

# %%
results_rfc = cvModel_rfc_final.transform(test_pca)
evaluator = MulticlassClassificationEvaluator(predictionCol='prediction')
print("F1 score of Random Forest Classifier Model is: ")
print(evaluator.evaluate(results_rfc, {evaluator.metricName: "f1"}))
print("Accuracy of Random Forest Classifier Model is: ")
print(evaluator.evaluate(results_rfc, {evaluator.metricName: "accuracy"}))
# Out:
# F1 score of Random Forest Classifier Model is:
# 0.9509662639027454
# Accuracy of Random Forest Classifier Model is:
# 0.9516129032258065

# %% [markdown]
# # Conclusion
#
# In this notebook I set out to predict user churn using Apache Spark using the user log data of the fictitious music streaming service Sparkify.
#
# I defined churn as users users who completely stopped using the service rather than also including those who only decided to downgrade to the free service offering.
#
# In the exploratory data analysis, I created several different features using window functions, and concatenated them with aggregated values of page views, in order to break down the data to just one row per user. These features were then compared across the two groups of users (churners and non-churners) to identify which ones could potentially be interesting in predicting churn.
#
# In the last part I then proceeded to further prepare the full dataset for machine learning algorithms by dropping features based on multicollinearity and appying PCA.
#
# Out of all these different models, the result of PCA outperforms the features after manual dimensional reduction, and Random Forest classifier did the best. Then, I performed some hyperparameter tuning on this algorithm using a parameter grid and cross validation to obtain an optimized model.
#
# Some improvements I could work on in the future:
#
# - Explore more parameters in model tuning session
# - A more automatic approach to filter out highly-related features
# - Take account of those users who downgraded their services
# - More focus on user behavior features
